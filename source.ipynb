# %%
# %sql
CREATE TABLE IF NOT EXISTS datamodelling.default.source_data (
    order_id INT, 
    order_date DATE, 
    customer_id INT, 
    customer_name STRING, 
    customer_email STRING, 
    product_id INT, 
    product_name STRING, 
    product_category STRING, 
    quantity INT, 
    unit_price DECIMAL, 
    payment_type STRING, 
    country STRING
);

# %%
# %sql
INSERT INTO datamodelling.default.source_data (
    order_id, order_date, customer_id, customer_name, customer_email, 
    product_id, product_name, product_category, quantity, unit_price, 
    payment_type, country
)
VALUES 
    (101, '2026-01-15', 5001, 'Alice Vance', 'alice.v@example.com', 201, 'Ergonomic Keyboard', 'Electronics', 1, 89.99, 'Credit Card', 'USA'),
    (102, '2026-01-16', 5002, 'Bob Chen', 'bchen88@example.com', 305, 'Organic Coffee Beans', 'Grocery', 2, 15.50, 'PayPal', 'Canada'),
    (103, '2026-01-16', 5003, 'Clara Meyer', 'clara.m@example.com', 412, 'Yoga Mat', 'Fitness', 1, 29.00, 'Debit Card', 'Germany'),
    (104, '2026-01-17', 5001, 'Alice Vance', 'alice.v@example.com', 202, 'Wireless Mouse', 'Electronics', 1, 45.00, 'Credit Card', 'USA'),
    (105, '2026-01-18', 5004, 'David Smith', 'dsmith@example.com', 550, 'Running Shoes', 'Apparel', 1, 120.00, 'Apple Pay', 'UK');

# %%
# %sql
select * from datamodelling.default.source_data
